# %%
# Built-in = already inside Python
# External = need to install

# | Feature      | Built-in Modules        | External Modules       |
# | ------------ | ----------------------- | ---------------------- |
# | Installation | Not required            | Required (pip)         |
# | Source       | Python standard library | Community / companies  |
# | Availability | Always available        | Depends on environment |

# %%
# Built-in Modules

# High Priority
import datetime
import re
import json
import os
import logging
import statistics

# Medium Priority
import collections
import itertools
import functools
import sys

# Low Priority
import copy
import time
import math
import random

# External Modules

# Core Foundation
import pandas
import numpy
import matplotlib
import seaborn
import plotly

# Database
import sqlalchemy
import psycopg2
import pyarrow

# Role-dependent
import requests
import sklearn
import statsmodels
import xgboost

# %%
# datetime is a built-in module used to work in data analytics, ETL pipelines, logging, scheduling jobs

import datetime
from datetime import datetime, date, time, timedelta

# | Class       | Purpose                  |
# | ----------- | ------------------------ |
# | `date`      | Only date                |
# | `time`      | Only time                |
# | `datetime`  | Date + time              |
# | `timedelta` | Difference between dates |
# | `timezone`  | Timezone handling        |

# %%
now = datetime.now()
print(now)
print(now.year)
print(now.month)
print(now.day)
print(now.hour)
# Out:
# 2026-05-02 13:21:10.265808
# 2026
# 5
# 2
# 13

# %%
date_str = "2026-05-02"
dt = datetime.strptime(date_str, "%Y-%m-%d")
print(dt)
# Out:
# 2026-05-02 00:00:00
